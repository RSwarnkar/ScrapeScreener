# %%
import requests as rq
import pandas as pd 
import time
import datetime
from bs4 import BeautifulSoup
import re
import os

# %%
folder_path = "output/06082024200748" ## UPDATE THIS 
df = pd.read_csv("screener-stocks-list.csv")
df.head(7)
# Out:
#   Screener Stock Symbol   Url Segment
# 0                526433  consolidated
# 1                532407  consolidated
# 2                544021  consolidated
# 3            AARTIDRUGS  consolidated
# 4              AARTIIND  consolidated
# 5            AARTIPHARM  consolidated
# 6             AARTISURF  consolidated

# %%
folder_path = "output/06082024200748" ## UPDATE THIS

# %%
stock_symbol1 = "AARTIIND" # "544021"
stock_symbol2 = "544021"
path1 = folder_path + "/" + stock_symbol1 + ".xlsx"
path2 = folder_path + "/" + stock_symbol2 + ".xlsx"

df_data1 =  pd.read_excel(path1, sheet_name="Quarterly Results")
df_data2 =  pd.read_excel(path2, sheet_name="Quarterly Results")

# Add Stockname column: 
df_data1['Stockname'] = stock_symbol1
df_data2['Stockname'] = stock_symbol2

column_to_move1 = df_data1.pop("Stockname")
df_data1.insert(1, "Stockname", column_to_move1)

column_to_move2 = df_data2.pop("Stockname")
df_data2.insert(1, "Stockname", column_to_move2)

# %%
df_data1
# Out:
#     Quarterly Results Stockname Mar 2021 Jun 2021 Sep 2021 Dec 2021 Mar 2022  \
# 0               Sales  AARTIIND     1209     1317     1256     2076     1756
# 1            Expenses  AARTIIND      949     1003     1001     1186     1417
# 2    Operating Profit  AARTIIND      260      314      255      890      339
# 3               OPM %  AARTIIND      22%      24%      20%      43%      19%
# 4        Other Income  AARTIIND        0        0        1        0        0
# 5            Interest  AARTIIND       22       38       14       24       31
# 6        Depreciation  AARTIIND       66       69       57       57       77
# 7   Profit before tax  AARTIIND      173      207      184      809      231
# 8               Tax %  AARTIIND      19%      20%      18%      10%      16%
# 9          Net Profit  AARTIIND      139      165      150      725      194
# 10          EPS in Rs  AARTIIND     3.91     4.55     4.14    20.01     5.34
# ...

# %%
df_data2
# Out:
#     Quarterly Results Stockname Jun 2022 Sep 2022 Dec 2022 Mar 2023 Jun 2023  \
# 0               Sales    544021      157      178      176      232      220
# 1            Expenses    544021      135      148      143      197      186
# 2    Operating Profit    544021       22       29       32       35       34
# 3               OPM %    544021      14%      16%      18%      15%      15%
# 4        Other Income    544021       10       10       10       11       13
# 5            Interest    544021        0        0        0        0        0
# 6        Depreciation    544021        4        5        5        5        5
# 7   Profit before tax    544021       27       34       38       41       42
# 8               Tax %    544021      22%      25%      25%      23%      23%
# 9          Net Profit    544021       21       26       28       32       32
# 10          EPS in Rs    544021     5.28     6.38     7.06     7.82     7.96
# ...

# %%
df3 = pd.concat([df_data1, df_data2], ignore_index=True, sort=False)

# %%
df3
# Out:
#     Quarterly Results Stockname Mar 2021 Jun 2021 Sep 2021 Dec 2021 Mar 2022  \
# 0               Sales  AARTIIND     1209     1317     1256     2076     1756
# 1            Expenses  AARTIIND      949     1003     1001     1186     1417
# 2    Operating Profit  AARTIIND      260      314      255      890      339
# 3               OPM %  AARTIIND      22%      24%      20%      43%      19%
# 4        Other Income  AARTIIND        0        0        1        0        0
# 5            Interest  AARTIIND       22       38       14       24       31
# 6        Depreciation  AARTIIND       66       69       57       57       77
# 7   Profit before tax  AARTIIND      173      207      184      809      231
# 8               Tax %  AARTIIND      19%      20%      18%      10%      16%
# 9          Net Profit  AARTIIND      139      165      150      725      194
# 10          EPS in Rs  AARTIIND     3.91     4.55     4.14    20.01     5.34
# ...

# %%
df3.describe()
# Out:
#        Quarterly Results Stockname Mar 2021 Jun 2021 Sep 2021 Dec 2021  \
# count                 24        24       11       11       11       11
# unique                12         2       11       11       11       11
# top                Sales  AARTIIND     1209     1317     1256     2076
# freq                   2        12        1        1        1        1
#
#        Mar 2022 Jun 2022 Sep 2022 Dec 2022 Mar 2023 Jun 2023 Sep 2023  \
# count        11       22       22       22       22       22       22
# unique       11       21       20       21       20       21       21
# top        1756        0      16%        0      15%        0        0
# freq          1        2        2        2        2        2        2
#
#        Dec 2023 Mar 2024 Jun 2024
# count        22       22       11
# unique       22       22       11
# top        1732     1773      197
# freq          1        1        1

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Quarterly Results  24 non-null     object
#  1   Stockname          24 non-null     object
#  2   Mar 2021           11 non-null     object
#  3   Jun 2021           11 non-null     object
#  4   Sep 2021           11 non-null     object
#  5   Dec 2021           11 non-null     object
#  6   Mar 2022           11 non-null     object
#  7   Jun 2022           22 non-null     object
#  8   Sep 2022           22 non-null     object
#  9   Dec 2022           22 non-null     object
#  10  Mar 2023           22 non-null     object
#  11  Jun 2023           22 non-null     object
#  12  Sep 2023           22 non-null     object
#  13  Dec 2023           22 non-null     object
#  14  Mar 2024           22 non-null     object
#  15  Jun 2024           11 non-null     object
# ...
